# %% [markdown]
# # Even / Odd training small_vol
# N2N (Noise2Noise) denoising del volumen empiar11415. Utiliza 2 volúmenes $V_1$ y $V_2$, donde $V_1$ es el volumen formado por los slices Z pares "even" y $V_2$ es el volumen formado por los slices Z impares "odd".
#
# Todos los ficheros temporales se crean en `/nas/vruiz/cryoCARE/empiar11415`.

# %%
# %pip install tensorflow==2.4

# %% [markdown]
# ## Creamos $V_1$ y $V_2$

# %%
# %run split_even_odd.ipynb
# Out:
# noisy.shape=(32, 256, 256)
# Writing /nas/vruiz/cryoCARE/small_vol/even.mrc
# even.shape=(20, 256, 256)
# Writing /nas/vruiz/cryoCARE/small_vol/odd.mrc
# odd.shape=(20, 256, 256)

# %% [markdown]
# ## Configuramos cryoCARE

# %%
# %%writefile /nas/vruiz/cryoCARE/small_vol/train_data_config__evenodd.json
# {
#     "even": ["even.mrc"],
#     "odd": ["odd.mrc"],
#     "mask": [""],
#     "patch_shape": [8, 8, 8],
#     "num_slices": 360,
#     "split": 0.9,
#     "tilt_axis": "Y",
#     "n_normalization_samples": 200,
#     "path": "./even_odd_data",
#     "overwrite": "True"
# }
# Out:
# Overwriting /nas/vruiz/cryoCARE/small_vol/train_data_config__evenodd.json

# %%
# %%bash
# cd /nas/vruiz/cryoCARE/small_vol
# source ~/envs/cryoCARE/bin/activate
# cryoCARE_extract_train_data.py --conf train_data_config__evenodd.json
# Out:
# 2025-10-21 14:45:10.459384: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# even.data.shape=(20, 256, 256), sample_shape=[8, 8, 8]
# Computing normalization parameters:
# 100%|██████████| 200/200 [00:00<00:00, 14856.30it/s]

# %% [markdown]
# ## Entrenamos

# %%
# %%writefile /nas/vruiz/cryoCARE/small_vol/train_config__evenodd.json
# {
#   "train_data": "./even_odd_data",
#   "epochs": 200,
#   "steps_per_epoch": 200,
#   "batch_size": 16,
#   "unet_kern_size": 3,
#   "unet_n_depth": 3,
#   "unet_n_first": 16,
#   "learning_rate": 0.0004,
#   "model_name": "model",
#   "path": "./",
#   "gpu_id": [1]
# }
# Out:
# Overwriting /nas/vruiz/cryoCARE/small_vol/train_config__evenodd.json

# %%
# %%bash
# cd /nas/vruiz/cryoCARE/small_vol
# source ~/envs/cryoCARE/bin/activate
# cryoCARE_train.py --conf train_config__evenodd.json
# Out:
# 2025-10-21 14:45:18.160201: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-21 14:45:20.155520: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2025-10-21 14:45:20.156299: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2025-10-21 14:45:20.176333: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:45:20.178665: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:c1:00.0 name: NVIDIA A30 computeCapability: 8.0
# coreClock: 1.44GHz coreCount: 56 deviceMemorySize: 23.60GiB deviceMemoryBandwidth: 869.04GiB/s
# 2025-10-21 14:45:20.178729: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:45:20.178900: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:41:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.73GiB deviceMemoryBandwidth: 836.37GiB/s
# 2025-10-21 14:45:20.178915: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-21 14:45:20.183598: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-21 14:45:20.183632: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2025-10-21 14:45:20.185950: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2025-10-21 14:45:20.187188: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2025-10-21 14:45:20.190649: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2025-10-21 14:45:20.192406: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2025-10-21 14:45:20.193792: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-21 14:45:20.193865: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:45:20.195221: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:45:20.195451: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:45:20.196798: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:45:20.196962: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2025-10-21 14:45:20.218455: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2025-10-21 14:45:20.218547: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:45:20.218732: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:41:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.73GiB deviceMemoryBandwidth: 836.37GiB/s
# 2025-10-21 14:45:20.218747: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-21 14:45:20.218759: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-21 14:45:20.218768: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2025-10-21 14:45:20.218776: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2025-10-21 14:45:20.218785: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2025-10-21 14:45:20.218793: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2025-10-21 14:45:20.218801: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2025-10-21 14:45:20.218809: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-21 14:45:20.218863: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:45:20.219098: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:45:20.219277: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 1
# 2025-10-21 14:45:20.219309: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-21 14:45:20.701301: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-21 14:45:20.701348: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      1
# 2025-10-21 14:45:20.701355: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   N
# 2025-10-21 14:45:20.701610: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:45:20.701866: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:45:20.702072: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:45:20.702244: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 28520 MB memory) -> physical GPU (device: 1, name: Tesla V100-PCIE-32GB, pci bus id: 0000:41:00.0, compute capability: 7.0)
# WARNING:tensorflow:NCCL is not supported when using virtual GPUs, fallingback to reduction to one device
# 2025-10-21 14:45:20.927260: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:656] In AUTO-mode, and switching to DATA-based sharding, instead of FILE-based sharding as we cannot find appropriate reader dataset op(s) to shard. Error: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_2"
# op: "FlatMapDataset"
# input: "TensorDataset/_1"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_flat_map_fn_645"
#     }
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: 8
#         }
#         dim {
#           size: 8
#         }
#         dim {
#           size: 8
#         }
#         dim {
#           size: 1
#         }
#       }
#       shape {
#         dim {
#           size: 8
#         }
#         dim {
#           size: 8
#         }
#         dim {
#           size: 8
#         }
#         dim {
#           size: 1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_FLOAT
#       type: DT_FLOAT
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2025-10-21 14:45:20.935980: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2025-10-21 14:45:20.936286: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2595155000 Hz
# Looking for GPU with ID: 1
# GPU 1 successfully found
# 0 1
# 1 8
# 2 8
# 3 8
# 4 1
# Epoch 1/200
# 2025-10-21 14:45:23.756763: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-21 14:45:25.012997: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2025-10-21 14:45:25.069843: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2025-10-21 14:45:25.708524: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-21 14:45:26.000027: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2025-10-21 14:45:47.254224: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:656] In AUTO-mode, and switching to DATA-based sharding, instead of FILE-based sharding as we cannot find appropriate reader dataset op(s) to shard. Error: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_2"
# op: "FlatMapDataset"
# input: "TensorDataset/_1"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_flat_map_fn_689"
#     }
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: 8
#         }
#         dim {
#           size: 8
#         }
#         dim {
#           size: 8
#         }
#         dim {
#           size: 1
#         }
#       }
#       shape {
#         dim {
#           size: 8
#         }
#         dim {
#           size: 8
#         }
#         dim {
#           size: 8
#         }
#         dim {
#           size: 1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_FLOAT
#       type: DT_FLOAT
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 200/200 [==============================] - 38s 70ms/step - loss: 0.7528 - mse: 0.7528 - mae: 0.6693 - val_loss: 0.6295 - val_mse: 0.6295 - val_mae: 0.6249
# Epoch 2/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.5873 - mse: 0.5873 - mae: 0.5978 - val_loss: 0.6128 - val_mse: 0.6128 - val_mae: 0.6154
# Epoch 3/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.5637 - mse: 0.5637 - mae: 0.5855 - val_loss: 0.5923 - val_mse: 0.5923 - val_mae: 0.6059
# Epoch 4/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.5583 - mse: 0.5583 - mae: 0.5831 - val_loss: 0.5799 - val_mse: 0.5799 - val_mae: 0.5991
# Epoch 5/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.5540 - mse: 0.5540 - mae: 0.5793 - val_loss: 0.5784 - val_mse: 0.5784 - val_mae: 0.5953
# Epoch 6/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.5458 - mse: 0.5458 - mae: 0.5739 - val_loss: 0.5852 - val_mse: 0.5852 - val_mae: 0.6014
# Epoch 7/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.5456 - mse: 0.5456 - mae: 0.5746 - val_loss: 0.5857 - val_mse: 0.5857 - val_mae: 0.6001
# Epoch 8/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.5388 - mse: 0.5388 - mae: 0.5703 - val_loss: 0.5820 - val_mse: 0.5820 - val_mae: 0.5956
# Epoch 9/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.5297 - mse: 0.5297 - mae: 0.5661 - val_loss: 0.5878 - val_mse: 0.5878 - val_mae: 0.6001
# Epoch 10/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.5182 - mse: 0.5182 - mae: 0.5600 - val_loss: 0.5970 - val_mse: 0.5970 - val_mae: 0.6064
# Epoch 11/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4974 - mse: 0.4974 - mae: 0.5493 - val_loss: 0.6266 - val_mse: 0.6266 - val_mae: 0.6180
# Epoch 12/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4766 - mse: 0.4766 - mae: 0.5383 - val_loss: 0.6464 - val_mse: 0.6464 - val_mae: 0.6265
# Epoch 13/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4485 - mse: 0.4485 - mae: 0.5214 - val_loss: 0.6528 - val_mse: 0.6528 - val_mae: 0.6303
# Epoch 14/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4291 - mse: 0.4291 - mae: 0.5098 - val_loss: 0.6680 - val_mse: 0.6680 - val_mae: 0.6405
# Epoch 15/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4097 - mse: 0.4097 - mae: 0.4986 - val_loss: 0.6977 - val_mse: 0.6977 - val_mae: 0.6532
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# Epoch 16/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.3909 - mse: 0.3909 - mae: 0.4867 - val_loss: 0.6940 - val_mse: 0.6940 - val_mae: 0.6525
# Epoch 17/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.3804 - mse: 0.3804 - mae: 0.4800 - val_loss: 0.7117 - val_mse: 0.7117 - val_mae: 0.6573
# Epoch 18/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.3736 - mse: 0.3736 - mae: 0.4758 - val_loss: 0.7158 - val_mse: 0.7158 - val_mae: 0.6608
# Epoch 19/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.3657 - mse: 0.3657 - mae: 0.4707 - val_loss: 0.7426 - val_mse: 0.7426 - val_mae: 0.6746
# Epoch 20/200
# 200/200 [==============================] - 2s 10ms/step - loss: 0.3581 - mse: 0.3581 - mae: 0.4651 - val_loss: 0.7302 - val_mse: 0.7302 - val_mae: 0.6662
# Epoch 21/200
# 200/200 [==============================] - 2s 10ms/step - loss: 0.3553 - mse: 0.3553 - mae: 0.4635 - val_loss: 0.7710 - val_mse: 0.7710 - val_mae: 0.6838
# Epoch 22/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3498 - mse: 0.3498 - mae: 0.4600 - val_loss: 0.7559 - val_mse: 0.7559 - val_mae: 0.6796
# Epoch 23/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.3438 - mse: 0.3438 - mae: 0.4558 - val_loss: 0.7691 - val_mse: 0.7691 - val_mae: 0.6840
# Epoch 24/200
# 200/200 [==============================] - 2s 10ms/step - loss: 0.3409 - mse: 0.3409 - mae: 0.4542 - val_loss: 0.7748 - val_mse: 0.7748 - val_mae: 0.6884
# Epoch 25/200
# 200/200 [==============================] - 2s 9ms/step - loss: 0.3355 - mse: 0.3355 - mae: 0.4502 - val_loss: 0.7850 - val_mse: 0.7850 - val_mae: 0.6927
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 26/200
# 200/200 [==============================] - 2s 10ms/step - loss: 0.3284 - mse: 0.3284 - mae: 0.4456 - val_loss: 0.7987 - val_mse: 0.7987 - val_mae: 0.7003
# Epoch 27/200
# 200/200 [==============================] - 2s 9ms/step - loss: 0.3264 - mse: 0.3264 - mae: 0.4437 - val_loss: 0.7889 - val_mse: 0.7889 - val_mae: 0.6941
# Epoch 28/200
# 200/200 [==============================] - 2s 10ms/step - loss: 0.3235 - mse: 0.3235 - mae: 0.4419 - val_loss: 0.8419 - val_mse: 0.8419 - val_mae: 0.7172
# Epoch 29/200
# 200/200 [==============================] - 2s 9ms/step - loss: 0.3225 - mse: 0.3225 - mae: 0.4411 - val_loss: 0.8162 - val_mse: 0.8162 - val_mae: 0.7063
# Epoch 30/200
# 200/200 [==============================] - 2s 10ms/step - loss: 0.3194 - mse: 0.3194 - mae: 0.4393 - val_loss: 0.8110 - val_mse: 0.8110 - val_mae: 0.7039
# Epoch 31/200
# 200/200 [==============================] - 2s 9ms/step - loss: 0.3182 - mse: 0.3182 - mae: 0.4379 - val_loss: 0.8316 - val_mse: 0.8316 - val_mae: 0.7111
# Epoch 32/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3165 - mse: 0.3165 - mae: 0.4372 - val_loss: 0.8239 - val_mse: 0.8239 - val_mae: 0.7088
# Epoch 33/200
# 200/200 [==============================] - 2s 8ms/step - loss: 0.3123 - mse: 0.3123 - mae: 0.4337 - val_loss: 0.8258 - val_mse: 0.8258 - val_mae: 0.7116
# Epoch 34/200
# 200/200 [==============================] - 2s 10ms/step - loss: 0.3112 - mse: 0.3112 - mae: 0.4331 - val_loss: 0.8444 - val_mse: 0.8444 - val_mae: 0.7202
# Epoch 35/200
# 200/200 [==============================] - 2s 10ms/step - loss: 0.3093 - mse: 0.3093 - mae: 0.4318 - val_loss: 0.8666 - val_mse: 0.8666 - val_mae: 0.7285
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 36/200
# 200/200 [==============================] - 2s 10ms/step - loss: 0.3074 - mse: 0.3074 - mae: 0.4302 - val_loss: 0.8503 - val_mse: 0.8503 - val_mae: 0.7210
# Epoch 37/200
# 200/200 [==============================] - 2s 10ms/step - loss: 0.3064 - mse: 0.3064 - mae: 0.4295 - val_loss: 0.8561 - val_mse: 0.8561 - val_mae: 0.7250
# Epoch 38/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3048 - mse: 0.3048 - mae: 0.4284 - val_loss: 0.8547 - val_mse: 0.8547 - val_mae: 0.7213
# Epoch 39/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.3034 - mse: 0.3034 - mae: 0.4276 - val_loss: 0.8546 - val_mse: 0.8546 - val_mae: 0.7233
# Epoch 40/200
# 200/200 [==============================] - 2s 10ms/step - loss: 0.3018 - mse: 0.3018 - mae: 0.4266 - val_loss: 0.8723 - val_mse: 0.8723 - val_mae: 0.7283
# Epoch 41/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.3027 - mse: 0.3027 - mae: 0.4271 - val_loss: 0.8728 - val_mse: 0.8728 - val_mae: 0.7295
# Epoch 42/200
# 200/200 [==============================] - 2s 10ms/step - loss: 0.3000 - mse: 0.3000 - mae: 0.4247 - val_loss: 0.8610 - val_mse: 0.8610 - val_mae: 0.7265
# Epoch 43/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2988 - mse: 0.2988 - mae: 0.4244 - val_loss: 0.8556 - val_mse: 0.8556 - val_mae: 0.7224
# Epoch 44/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.3000 - mse: 0.3000 - mae: 0.4252 - val_loss: 0.8730 - val_mse: 0.8730 - val_mae: 0.7299
# Epoch 45/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2979 - mse: 0.2979 - mae: 0.4235 - val_loss: 0.8597 - val_mse: 0.8597 - val_mae: 0.7228
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 46/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2964 - mse: 0.2964 - mae: 0.4221 - val_loss: 0.8813 - val_mse: 0.8813 - val_mae: 0.7319
# Epoch 47/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2954 - mse: 0.2954 - mae: 0.4219 - val_loss: 0.8832 - val_mse: 0.8832 - val_mae: 0.7337
# Epoch 48/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2963 - mse: 0.2963 - mae: 0.4223 - val_loss: 0.8858 - val_mse: 0.8858 - val_mae: 0.7373
# Epoch 49/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2954 - mse: 0.2954 - mae: 0.4219 - val_loss: 0.8810 - val_mse: 0.8810 - val_mae: 0.7328
# Epoch 50/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2946 - mse: 0.2946 - mae: 0.4214 - val_loss: 0.9008 - val_mse: 0.9008 - val_mae: 0.7420
# Epoch 51/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2949 - mse: 0.2949 - mae: 0.4214 - val_loss: 0.8832 - val_mse: 0.8832 - val_mae: 0.7344
# Epoch 52/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2940 - mse: 0.2940 - mae: 0.4209 - val_loss: 0.8793 - val_mse: 0.8793 - val_mae: 0.7335
# Epoch 53/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2956 - mse: 0.2956 - mae: 0.4219 - val_loss: 0.8872 - val_mse: 0.8872 - val_mae: 0.7368
# Epoch 54/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2919 - mse: 0.2919 - mae: 0.4194 - val_loss: 0.8884 - val_mse: 0.8884 - val_mae: 0.7359
# Epoch 55/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2945 - mse: 0.2945 - mae: 0.4212 - val_loss: 0.9006 - val_mse: 0.9006 - val_mae: 0.7400
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 56/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2910 - mse: 0.2910 - mae: 0.4185 - val_loss: 0.8946 - val_mse: 0.8946 - val_mae: 0.7399
# Epoch 57/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2923 - mse: 0.2923 - mae: 0.4196 - val_loss: 0.8886 - val_mse: 0.8886 - val_mae: 0.7374
# Epoch 58/200
# 200/200 [==============================] - 2s 9ms/step - loss: 0.2922 - mse: 0.2922 - mae: 0.4196 - val_loss: 0.9116 - val_mse: 0.9116 - val_mae: 0.7472
# Epoch 59/200
# 200/200 [==============================] - 2s 8ms/step - loss: 0.2918 - mse: 0.2918 - mae: 0.4188 - val_loss: 0.8972 - val_mse: 0.8972 - val_mae: 0.7397
# Epoch 60/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2901 - mse: 0.2901 - mae: 0.4178 - val_loss: 0.9108 - val_mse: 0.9108 - val_mae: 0.7478
# Epoch 61/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2920 - mse: 0.2920 - mae: 0.4197 - val_loss: 0.9012 - val_mse: 0.9012 - val_mae: 0.7431
# Epoch 62/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2919 - mse: 0.2919 - mae: 0.4192 - val_loss: 0.9098 - val_mse: 0.9098 - val_mae: 0.7449
# Epoch 63/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2909 - mse: 0.2909 - mae: 0.4188 - val_loss: 0.8878 - val_mse: 0.8878 - val_mae: 0.7365
# Epoch 64/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2893 - mse: 0.2893 - mae: 0.4169 - val_loss: 0.9207 - val_mse: 0.9207 - val_mae: 0.7494
# Epoch 65/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2887 - mse: 0.2887 - mae: 0.4168 - val_loss: 0.8923 - val_mse: 0.8923 - val_mae: 0.7389
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 66/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2886 - mse: 0.2886 - mae: 0.4167 - val_loss: 0.8827 - val_mse: 0.8827 - val_mae: 0.7339
# Epoch 67/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2897 - mse: 0.2897 - mae: 0.4176 - val_loss: 0.8772 - val_mse: 0.8772 - val_mae: 0.7343
# Epoch 68/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2892 - mse: 0.2892 - mae: 0.4169 - val_loss: 0.9023 - val_mse: 0.9023 - val_mae: 0.7426
# Epoch 69/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2898 - mse: 0.2898 - mae: 0.4176 - val_loss: 0.9075 - val_mse: 0.9075 - val_mae: 0.7429
# Epoch 70/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2902 - mse: 0.2902 - mae: 0.4181 - val_loss: 0.9047 - val_mse: 0.9047 - val_mae: 0.7434
# Epoch 71/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2899 - mse: 0.2899 - mae: 0.4179 - val_loss: 0.8956 - val_mse: 0.8956 - val_mae: 0.7378
# Epoch 72/200
# 200/200 [==============================] - 2s 10ms/step - loss: 0.2900 - mse: 0.2900 - mae: 0.4181 - val_loss: 0.9068 - val_mse: 0.9068 - val_mae: 0.7452
# Epoch 73/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2881 - mse: 0.2881 - mae: 0.4162 - val_loss: 0.8940 - val_mse: 0.8940 - val_mae: 0.7377
# Epoch 74/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2873 - mse: 0.2873 - mae: 0.4160 - val_loss: 0.9070 - val_mse: 0.9070 - val_mae: 0.7435
# Epoch 75/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2881 - mse: 0.2881 - mae: 0.4161 - val_loss: 0.9046 - val_mse: 0.9046 - val_mae: 0.7419
#
# Epoch 00075: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 76/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2880 - mse: 0.2880 - mae: 0.4163 - val_loss: 0.8961 - val_mse: 0.8961 - val_mae: 0.7386
# Epoch 77/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2881 - mse: 0.2881 - mae: 0.4168 - val_loss: 0.8962 - val_mse: 0.8962 - val_mae: 0.7401
# Epoch 78/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2877 - mse: 0.2877 - mae: 0.4162 - val_loss: 0.8778 - val_mse: 0.8778 - val_mae: 0.7332
# Epoch 79/200
# 200/200 [==============================] - 2s 10ms/step - loss: 0.2873 - mse: 0.2873 - mae: 0.4157 - val_loss: 0.9187 - val_mse: 0.9187 - val_mae: 0.7487
# Epoch 80/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2887 - mse: 0.2887 - mae: 0.4169 - val_loss: 0.9104 - val_mse: 0.9104 - val_mae: 0.7467
# Epoch 81/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2885 - mse: 0.2885 - mae: 0.4164 - val_loss: 0.9126 - val_mse: 0.9126 - val_mae: 0.7457
# Epoch 82/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2866 - mse: 0.2866 - mae: 0.4152 - val_loss: 0.9184 - val_mse: 0.9184 - val_mae: 0.7471
# Epoch 83/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2877 - mse: 0.2877 - mae: 0.4163 - val_loss: 0.8949 - val_mse: 0.8949 - val_mae: 0.7404
# Epoch 84/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2862 - mse: 0.2862 - mae: 0.4148 - val_loss: 0.9215 - val_mse: 0.9215 - val_mae: 0.7503
# Epoch 85/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2884 - mse: 0.2884 - mae: 0.4165 - val_loss: 0.8905 - val_mse: 0.8905 - val_mae: 0.7375
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 86/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2870 - mse: 0.2870 - mae: 0.4156 - val_loss: 0.8981 - val_mse: 0.8981 - val_mae: 0.7404
# Epoch 87/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2880 - mse: 0.2880 - mae: 0.4166 - val_loss: 0.8968 - val_mse: 0.8968 - val_mae: 0.7389
# Epoch 88/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2872 - mse: 0.2872 - mae: 0.4160 - val_loss: 0.9109 - val_mse: 0.9109 - val_mae: 0.7449
# Epoch 89/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2877 - mse: 0.2877 - mae: 0.4158 - val_loss: 0.9109 - val_mse: 0.9109 - val_mae: 0.7436
# Epoch 90/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2884 - mse: 0.2884 - mae: 0.4167 - val_loss: 0.9228 - val_mse: 0.9228 - val_mae: 0.7506
# Epoch 91/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2864 - mse: 0.2864 - mae: 0.4151 - val_loss: 0.8998 - val_mse: 0.8998 - val_mae: 0.7425
# Epoch 92/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2874 - mse: 0.2874 - mae: 0.4158 - val_loss: 0.9195 - val_mse: 0.9195 - val_mae: 0.7494
# Epoch 93/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2889 - mse: 0.2889 - mae: 0.4174 - val_loss: 0.9293 - val_mse: 0.9293 - val_mae: 0.7513
# Epoch 94/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2875 - mse: 0.2875 - mae: 0.4160 - val_loss: 0.9219 - val_mse: 0.9219 - val_mae: 0.7493
# Epoch 95/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2877 - mse: 0.2877 - mae: 0.4164 - val_loss: 0.9141 - val_mse: 0.9141 - val_mae: 0.7468
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 96/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2867 - mse: 0.2867 - mae: 0.4151 - val_loss: 0.9073 - val_mse: 0.9073 - val_mae: 0.7437
# Epoch 97/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2890 - mse: 0.2890 - mae: 0.4172 - val_loss: 0.8772 - val_mse: 0.8772 - val_mae: 0.7328
# Epoch 98/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2859 - mse: 0.2859 - mae: 0.4146 - val_loss: 0.9155 - val_mse: 0.9155 - val_mae: 0.7469
# Epoch 99/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2859 - mse: 0.2859 - mae: 0.4146 - val_loss: 0.8995 - val_mse: 0.8995 - val_mae: 0.7395
# Epoch 100/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2879 - mse: 0.2879 - mae: 0.4166 - val_loss: 0.8984 - val_mse: 0.8984 - val_mae: 0.7410
# Epoch 101/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2876 - mse: 0.2876 - mae: 0.4161 - val_loss: 0.9396 - val_mse: 0.9396 - val_mae: 0.7576
# Epoch 102/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2861 - mse: 0.2861 - mae: 0.4149 - val_loss: 0.9096 - val_mse: 0.9096 - val_mae: 0.7427
# Epoch 103/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2863 - mse: 0.2863 - mae: 0.4150 - val_loss: 0.9084 - val_mse: 0.9084 - val_mae: 0.7422
# Epoch 104/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2884 - mse: 0.2884 - mae: 0.4169 - val_loss: 0.9409 - val_mse: 0.9409 - val_mae: 0.7592
# Epoch 105/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2874 - mse: 0.2874 - mae: 0.4160 - val_loss: 0.9103 - val_mse: 0.9103 - val_mae: 0.7444
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 106/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2882 - mse: 0.2882 - mae: 0.4164 - val_loss: 0.9052 - val_mse: 0.9052 - val_mae: 0.7426
# Epoch 107/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2866 - mse: 0.2866 - mae: 0.4152 - val_loss: 0.9326 - val_mse: 0.9326 - val_mae: 0.7530
# Epoch 108/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2873 - mse: 0.2873 - mae: 0.4159 - val_loss: 0.9217 - val_mse: 0.9217 - val_mae: 0.7513
# Epoch 109/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2867 - mse: 0.2867 - mae: 0.4151 - val_loss: 0.9212 - val_mse: 0.9212 - val_mae: 0.7477
# Epoch 110/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2860 - mse: 0.2860 - mae: 0.4149 - val_loss: 0.9154 - val_mse: 0.9154 - val_mae: 0.7451
# Epoch 111/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2884 - mse: 0.2884 - mae: 0.4166 - val_loss: 0.9075 - val_mse: 0.9075 - val_mae: 0.7448
# Epoch 112/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2882 - mse: 0.2882 - mae: 0.4168 - val_loss: 0.9164 - val_mse: 0.9164 - val_mae: 0.7477
# Epoch 113/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2892 - mse: 0.2892 - mae: 0.4174 - val_loss: 0.8978 - val_mse: 0.8978 - val_mae: 0.7411
# Epoch 114/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2871 - mse: 0.2871 - mae: 0.4155 - val_loss: 0.9169 - val_mse: 0.9169 - val_mae: 0.7460
# Epoch 115/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2878 - mse: 0.2878 - mae: 0.4162 - val_loss: 0.9216 - val_mse: 0.9216 - val_mae: 0.7482
#
# Epoch 00115: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# Epoch 116/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2880 - mse: 0.2880 - mae: 0.4167 - val_loss: 0.9197 - val_mse: 0.9197 - val_mae: 0.7490
# Epoch 117/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2870 - mse: 0.2870 - mae: 0.4153 - val_loss: 0.9072 - val_mse: 0.9072 - val_mae: 0.7421
# Epoch 118/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2882 - mse: 0.2882 - mae: 0.4168 - val_loss: 0.8993 - val_mse: 0.8993 - val_mae: 0.7404
# Epoch 119/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2857 - mse: 0.2857 - mae: 0.4146 - val_loss: 0.9188 - val_mse: 0.9188 - val_mae: 0.7494
# Epoch 120/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2877 - mse: 0.2877 - mae: 0.4163 - val_loss: 0.8916 - val_mse: 0.8916 - val_mae: 0.7372
# Epoch 121/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2857 - mse: 0.2857 - mae: 0.4146 - val_loss: 0.9311 - val_mse: 0.9311 - val_mae: 0.7542
# Epoch 122/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2871 - mse: 0.2871 - mae: 0.4157 - val_loss: 0.8978 - val_mse: 0.8978 - val_mae: 0.7427
# Epoch 123/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2869 - mse: 0.2869 - mae: 0.4155 - val_loss: 0.8835 - val_mse: 0.8835 - val_mae: 0.7352
# Epoch 124/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2854 - mse: 0.2854 - mae: 0.4142 - val_loss: 0.9075 - val_mse: 0.9075 - val_mae: 0.7445
# Epoch 125/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2890 - mse: 0.2890 - mae: 0.4169 - val_loss: 0.9027 - val_mse: 0.9027 - val_mae: 0.7419
#
# Epoch 00125: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# Epoch 126/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2884 - mse: 0.2884 - mae: 0.4169 - val_loss: 0.9421 - val_mse: 0.9421 - val_mae: 0.7581
# Epoch 127/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2871 - mse: 0.2871 - mae: 0.4154 - val_loss: 0.9029 - val_mse: 0.9029 - val_mae: 0.7435
# Epoch 128/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2848 - mse: 0.2848 - mae: 0.4137 - val_loss: 0.9198 - val_mse: 0.9198 - val_mae: 0.7481
# Epoch 129/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2870 - mse: 0.2870 - mae: 0.4154 - val_loss: 0.9211 - val_mse: 0.9211 - val_mae: 0.7508
# Epoch 130/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2864 - mse: 0.2864 - mae: 0.4150 - val_loss: 0.9112 - val_mse: 0.9112 - val_mae: 0.7447
# Epoch 131/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2852 - mse: 0.2852 - mae: 0.4142 - val_loss: 0.9291 - val_mse: 0.9291 - val_mae: 0.7539
# Epoch 132/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2884 - mse: 0.2884 - mae: 0.4170 - val_loss: 0.9166 - val_mse: 0.9166 - val_mae: 0.7464
# Epoch 133/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2877 - mse: 0.2877 - mae: 0.4159 - val_loss: 0.9224 - val_mse: 0.9224 - val_mae: 0.7510
# Epoch 134/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2854 - mse: 0.2854 - mae: 0.4146 - val_loss: 0.9039 - val_mse: 0.9039 - val_mae: 0.7443
# Epoch 135/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2854 - mse: 0.2854 - mae: 0.4145 - val_loss: 0.9261 - val_mse: 0.9261 - val_mae: 0.7510
#
# Epoch 00135: ReduceLROnPlateau reducing learning rate to 4.882812376649781e-08.
# Epoch 136/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2861 - mse: 0.2861 - mae: 0.4149 - val_loss: 0.8948 - val_mse: 0.8948 - val_mae: 0.7396
# Epoch 137/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2870 - mse: 0.2870 - mae: 0.4152 - val_loss: 0.9174 - val_mse: 0.9174 - val_mae: 0.7502
# Epoch 138/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2881 - mse: 0.2881 - mae: 0.4165 - val_loss: 0.9236 - val_mse: 0.9236 - val_mae: 0.7475
# Epoch 139/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2864 - mse: 0.2864 - mae: 0.4155 - val_loss: 0.9190 - val_mse: 0.9190 - val_mae: 0.7487
# Epoch 140/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2871 - mse: 0.2871 - mae: 0.4157 - val_loss: 0.8794 - val_mse: 0.8794 - val_mae: 0.7322
# Epoch 141/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2891 - mse: 0.2891 - mae: 0.4172 - val_loss: 0.9178 - val_mse: 0.9178 - val_mae: 0.7476
# Epoch 142/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2864 - mse: 0.2864 - mae: 0.4150 - val_loss: 0.9033 - val_mse: 0.9033 - val_mae: 0.7419
# Epoch 143/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2859 - mse: 0.2859 - mae: 0.4148 - val_loss: 0.9120 - val_mse: 0.9120 - val_mae: 0.7464
# Epoch 144/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2869 - mse: 0.2869 - mae: 0.4155 - val_loss: 0.9161 - val_mse: 0.9161 - val_mae: 0.7455
# Epoch 145/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2875 - mse: 0.2875 - mae: 0.4159 - val_loss: 0.8829 - val_mse: 0.8829 - val_mae: 0.7316
#
# Epoch 00145: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
# Epoch 146/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2864 - mse: 0.2864 - mae: 0.4151 - val_loss: 0.9168 - val_mse: 0.9168 - val_mae: 0.7476
# Epoch 147/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2876 - mse: 0.2876 - mae: 0.4160 - val_loss: 0.9115 - val_mse: 0.9115 - val_mae: 0.7444
# Epoch 148/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2860 - mse: 0.2860 - mae: 0.4147 - val_loss: 0.9036 - val_mse: 0.9036 - val_mae: 0.7417
# Epoch 149/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2872 - mse: 0.2872 - mae: 0.4158 - val_loss: 0.9224 - val_mse: 0.9224 - val_mae: 0.7493
# Epoch 150/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2868 - mse: 0.2868 - mae: 0.4149 - val_loss: 0.8938 - val_mse: 0.8938 - val_mae: 0.7380
# Epoch 151/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2878 - mse: 0.2878 - mae: 0.4165 - val_loss: 0.9171 - val_mse: 0.9171 - val_mae: 0.7465
# Epoch 152/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2884 - mse: 0.2884 - mae: 0.4168 - val_loss: 0.9208 - val_mse: 0.9208 - val_mae: 0.7506
# Epoch 153/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2869 - mse: 0.2869 - mae: 0.4154 - val_loss: 0.9018 - val_mse: 0.9018 - val_mae: 0.7418
# Epoch 154/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2880 - mse: 0.2880 - mae: 0.4166 - val_loss: 0.9105 - val_mse: 0.9105 - val_mae: 0.7448
# Epoch 155/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2881 - mse: 0.2881 - mae: 0.4168 - val_loss: 0.9187 - val_mse: 0.9187 - val_mae: 0.7487
#
# Epoch 00155: ReduceLROnPlateau reducing learning rate to 1.2207030941624453e-08.
# Epoch 156/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2883 - mse: 0.2883 - mae: 0.4168 - val_loss: 0.8980 - val_mse: 0.8980 - val_mae: 0.7388
# Epoch 157/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2864 - mse: 0.2864 - mae: 0.4152 - val_loss: 0.9107 - val_mse: 0.9107 - val_mae: 0.7444
# Epoch 158/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2866 - mse: 0.2866 - mae: 0.4156 - val_loss: 0.9110 - val_mse: 0.9110 - val_mae: 0.7445
# Epoch 159/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2879 - mse: 0.2879 - mae: 0.4163 - val_loss: 0.9066 - val_mse: 0.9066 - val_mae: 0.7422
# Epoch 160/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2864 - mse: 0.2864 - mae: 0.4148 - val_loss: 0.9299 - val_mse: 0.9299 - val_mae: 0.7520
# Epoch 161/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2865 - mse: 0.2865 - mae: 0.4154 - val_loss: 0.8838 - val_mse: 0.8838 - val_mae: 0.7329
# Epoch 162/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2864 - mse: 0.2864 - mae: 0.4150 - val_loss: 0.9224 - val_mse: 0.9224 - val_mae: 0.7509
# Epoch 163/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2869 - mse: 0.2869 - mae: 0.4156 - val_loss: 0.8948 - val_mse: 0.8948 - val_mae: 0.7386
# Epoch 164/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2872 - mse: 0.2872 - mae: 0.4155 - val_loss: 0.9110 - val_mse: 0.9110 - val_mae: 0.7448
# Epoch 165/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2868 - mse: 0.2868 - mae: 0.4157 - val_loss: 0.8886 - val_mse: 0.8886 - val_mae: 0.7369
#
# Epoch 00165: ReduceLROnPlateau reducing learning rate to 6.103515470812226e-09.
# Epoch 166/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2882 - mse: 0.2882 - mae: 0.4168 - val_loss: 0.9374 - val_mse: 0.9374 - val_mae: 0.7556
# Epoch 167/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2869 - mse: 0.2869 - mae: 0.4153 - val_loss: 0.9257 - val_mse: 0.9257 - val_mae: 0.7494
# Epoch 168/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2873 - mse: 0.2873 - mae: 0.4159 - val_loss: 0.9190 - val_mse: 0.9190 - val_mae: 0.7479
# Epoch 169/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2895 - mse: 0.2895 - mae: 0.4174 - val_loss: 0.9020 - val_mse: 0.9020 - val_mae: 0.7403
# Epoch 170/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2868 - mse: 0.2868 - mae: 0.4154 - val_loss: 0.9264 - val_mse: 0.9264 - val_mae: 0.7505
# Epoch 171/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2851 - mse: 0.2851 - mae: 0.4142 - val_loss: 0.9165 - val_mse: 0.9165 - val_mae: 0.7474
# Epoch 172/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2882 - mse: 0.2882 - mae: 0.4168 - val_loss: 0.9071 - val_mse: 0.9071 - val_mae: 0.7442
# Epoch 173/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2845 - mse: 0.2845 - mae: 0.4135 - val_loss: 0.9348 - val_mse: 0.9348 - val_mae: 0.7552
# Epoch 174/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2858 - mse: 0.2858 - mae: 0.4143 - val_loss: 0.9255 - val_mse: 0.9255 - val_mae: 0.7536
# Epoch 175/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2866 - mse: 0.2866 - mae: 0.4154 - val_loss: 0.8915 - val_mse: 0.8915 - val_mae: 0.7390
#
# Epoch 00175: ReduceLROnPlateau reducing learning rate to 3.051757735406113e-09.
# Epoch 176/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2874 - mse: 0.2874 - mae: 0.4158 - val_loss: 0.8955 - val_mse: 0.8955 - val_mae: 0.7379
# Epoch 177/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2860 - mse: 0.2860 - mae: 0.4147 - val_loss: 0.9154 - val_mse: 0.9154 - val_mae: 0.7464
# Epoch 178/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2870 - mse: 0.2870 - mae: 0.4156 - val_loss: 0.9326 - val_mse: 0.9326 - val_mae: 0.7570
# Epoch 179/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2864 - mse: 0.2864 - mae: 0.4152 - val_loss: 0.9155 - val_mse: 0.9155 - val_mae: 0.7468
# Epoch 180/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2865 - mse: 0.2865 - mae: 0.4151 - val_loss: 0.9280 - val_mse: 0.9280 - val_mae: 0.7536
# Epoch 181/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2872 - mse: 0.2872 - mae: 0.4160 - val_loss: 0.9407 - val_mse: 0.9407 - val_mae: 0.7587
# Epoch 182/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2865 - mse: 0.2865 - mae: 0.4154 - val_loss: 0.9125 - val_mse: 0.9125 - val_mae: 0.7459
# Epoch 183/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2866 - mse: 0.2866 - mae: 0.4149 - val_loss: 0.8842 - val_mse: 0.8842 - val_mae: 0.7356
# Epoch 184/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2846 - mse: 0.2846 - mae: 0.4135 - val_loss: 0.9271 - val_mse: 0.9271 - val_mae: 0.7499
# Epoch 185/200
# 200/200 [==============================] - 2s 10ms/step - loss: 0.2876 - mse: 0.2876 - mae: 0.4160 - val_loss: 0.9174 - val_mse: 0.9174 - val_mae: 0.7473
#
# Epoch 00185: ReduceLROnPlateau reducing learning rate to 1.5258788677030566e-09.
# Epoch 186/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2870 - mse: 0.2870 - mae: 0.4157 - val_loss: 0.8996 - val_mse: 0.8996 - val_mae: 0.7385
# Epoch 187/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2870 - mse: 0.2870 - mae: 0.4155 - val_loss: 0.9333 - val_mse: 0.9333 - val_mae: 0.7547
# Epoch 188/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2863 - mse: 0.2863 - mae: 0.4152 - val_loss: 0.9039 - val_mse: 0.9039 - val_mae: 0.7439
# Epoch 189/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2872 - mse: 0.2872 - mae: 0.4157 - val_loss: 0.9088 - val_mse: 0.9088 - val_mae: 0.7434
# Epoch 190/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2872 - mse: 0.2872 - mae: 0.4158 - val_loss: 0.9131 - val_mse: 0.9131 - val_mae: 0.7453
# Epoch 191/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2878 - mse: 0.2878 - mae: 0.4159 - val_loss: 0.8804 - val_mse: 0.8804 - val_mae: 0.7327
# Epoch 192/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2887 - mse: 0.2887 - mae: 0.4167 - val_loss: 0.9028 - val_mse: 0.9028 - val_mae: 0.7442
# Epoch 193/200
# 200/200 [==============================] - 3s 13ms/step - loss: 0.2870 - mse: 0.2870 - mae: 0.4159 - val_loss: 0.9153 - val_mse: 0.9153 - val_mae: 0.7455
# Epoch 194/200
# 200/200 [==============================] - 2s 9ms/step - loss: 0.2880 - mse: 0.2880 - mae: 0.4163 - val_loss: 0.9102 - val_mse: 0.9102 - val_mae: 0.7468
# Epoch 195/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2872 - mse: 0.2872 - mae: 0.4158 - val_loss: 0.9266 - val_mse: 0.9266 - val_mae: 0.7528
#
# Epoch 00195: ReduceLROnPlateau reducing learning rate to 7.629394338515283e-10.
# Epoch 196/200
# 200/200 [==============================] - 2s 12ms/step - loss: 0.2873 - mse: 0.2873 - mae: 0.4160 - val_loss: 0.9242 - val_mse: 0.9242 - val_mae: 0.7513
# Epoch 197/200
# 200/200 [==============================] - 2s 8ms/step - loss: 0.2875 - mse: 0.2875 - mae: 0.4160 - val_loss: 0.8906 - val_mse: 0.8906 - val_mae: 0.7369
# Epoch 198/200
# 200/200 [==============================] - 2s 8ms/step - loss: 0.2872 - mse: 0.2872 - mae: 0.4160 - val_loss: 0.9212 - val_mse: 0.9212 - val_mae: 0.7512
# Epoch 199/200
# 200/200 [==============================] - 2s 9ms/step - loss: 0.2861 - mse: 0.2861 - mae: 0.4147 - val_loss: 0.9017 - val_mse: 0.9017 - val_mae: 0.7414
# Epoch 200/200
# 200/200 [==============================] - 2s 11ms/step - loss: 0.2860 - mse: 0.2860 - mae: 0.4148 - val_loss: 0.8965 - val_mse: 0.8965 - val_mae: 0.7371
# /home/jupyter-vruiz/envs/cryoCARE/lib/python3.8/site-packages/csbdeep/models/base_model.py:149: UserWarning: output path for model already exists, files may be overwritten: /nas/vruiz/cryoCARE/small_vol/model
#   warnings.warn('output path for model already exists, files may be overwritten: %s' % str(self.logdir.resolve()))
# Loading network weights from 'weights_best.h5'.

# %% [markdown]
# ## Inferimos

# %%
# %%writefile /nas/vruiz/cryoCARE/small_vol/predict_config__evenodd.json
# {
#     "path": "./model.tar.gz",
#     "even": ["small_vol.mrc"],
#     "odd": ["small_vol.mrc"],
#     "n_tiles": [1,1,1],
#     "output": "even_odd_denoised",
#     "overwrite": "True",
#     "gpu_id": [1]
# }
# Out:
# Overwriting /nas/vruiz/cryoCARE/small_vol/predict_config__evenodd.json

# %%
# %%bash
# cd /nas/vruiz/cryoCARE/small_vol
# pwd
# source ~/envs/cryoCARE/bin/activate
# cryoCARE_predict.py --conf predict_config__evenodd.json || true
# Out:
# /nas/vruiz/cryoCARE/small_vol
# 2025-10-21 14:54:10.025778: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-21 14:54:15.613825: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2025-10-21 14:54:15.614562: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2025-10-21 14:54:15.634270: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:54:15.635682: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:c1:00.0 name: NVIDIA A30 computeCapability: 8.0
# coreClock: 1.44GHz coreCount: 56 deviceMemorySize: 23.60GiB deviceMemoryBandwidth: 869.04GiB/s
# 2025-10-21 14:54:15.635744: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:54:15.635914: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:41:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.73GiB deviceMemoryBandwidth: 836.37GiB/s
# 2025-10-21 14:54:15.635929: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-21 14:54:15.640212: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-21 14:54:15.640246: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2025-10-21 14:54:15.642402: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2025-10-21 14:54:15.643732: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2025-10-21 14:54:15.647245: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2025-10-21 14:54:15.649122: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2025-10-21 14:54:15.650224: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-21 14:54:15.650302: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:54:15.651858: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:54:15.652075: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:54:15.653408: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:54:15.653567: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2025-10-21 14:54:15.746119: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2025-10-21 14:54:15.746266: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:54:15.746480: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:41:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.73GiB deviceMemoryBandwidth: 836.37GiB/s
# 2025-10-21 14:54:15.746499: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-21 14:54:15.746517: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-21 14:54:15.746527: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2025-10-21 14:54:15.746535: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2025-10-21 14:54:15.746543: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2025-10-21 14:54:15.746552: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2025-10-21 14:54:15.746560: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2025-10-21 14:54:15.746569: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-21 14:54:15.746623: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:54:15.746836: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:54:15.746998: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 1
# 2025-10-21 14:54:15.747024: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-21 14:54:16.239807: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-21 14:54:16.239844: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      1
# 2025-10-21 14:54:16.239851: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   N
# 2025-10-21 14:54:16.240094: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:54:16.240332: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:54:16.240533: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 14:54:16.240702: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 28520 MB memory) -> physical GPU (device: 1, name: Tesla V100-PCIE-32GB, pci bus id: 0000:41:00.0, compute capability: 7.0)
# 2025-10-21 14:54:16.403349: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2025-10-21 14:54:16.403713: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2595155000 Hz
# 2025-10-21 14:54:16.555486: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-21 14:54:17.794969: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2025-10-21 14:54:17.852905: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2025-10-21 14:54:18.599536: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-21 14:54:18.891669: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# Looking for GPU with ID: 1
# GPU 1 successfully found
# Loading network weights from 'weights_best.h5'.
# (32, 256, 256, 1)
# ['' '' '' '' '' '' '' ''
#  'cryoCARE                                                21-Oct-25  14:54:29     '
#  '']

# %%
import mrcfile
import numpy as np
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

# %%
def read_MRC(path_file):
    return mrcfile.read(mrc_file_path)

# %%
mrc_file_path = '/nas/vruiz/cryoCARE/small_vol/small_vol.mrc'
original_volume = read_MRC(mrc_file_path)

# %%
original_volume.shape
# Out:
# (32, 256, 256)

# %%
mrc_file_path = '/nas/vruiz/cryoCARE/small_vol/even_odd_denoised/small_vol.mrc'
denoised_volume = read_MRC(mrc_file_path)

# %%
denoised_volume.shape
# Out:
# (32, 256, 256)

# %%
# Choose a slice index in the middle of the volume for a good comparison
slice_idx = original_volume.shape[0] // 2

fig, axes = plt.subplots(1, 2, figsize=(20, 20))

# Plot the original slice z
im1 = axes[0].imshow(original_volume[slice_idx, :, :].T, cmap='gray', origin='lower')
axes[0].set_title(f'Original Slice Z={slice_idx}')
axes[0].grid(False)

# Plot the original slice z+1
im2 = axes[1].imshow(denoised_volume[slice_idx, :, :].T, cmap='gray', origin='lower')
axes[1].set_title(f'N2N Even/Odd Denoised Slice Z={slice_idx}')
axes[1].grid(False)

plt.tight_layout()
plt.show()

# %%
# %pip install "self_fourier_shell_correlation @ git+https://github.com/vicente-gonzalez-ruiz/self_fourier_shell_correlation"
# Out:
# Collecting self_fourier_shell_correlation@ git+https://github.com/vicente-gonzalez-ruiz/self_fourier_shell_correlation
#   Cloning https://github.com/vicente-gonzalez-ruiz/self_fourier_shell_correlation to /tmp/pip-install-q_0ksw3u/self-fourier-shell-correlation_027590dd128a4a3bae0a13fb157065d2
#   Running command git clone --filter=blob:none --quiet https://github.com/vicente-gonzalez-ruiz/self_fourier_shell_correlation /tmp/pip-install-q_0ksw3u/self-fourier-shell-correlation_027590dd128a4a3bae0a13fb157065d2
#   Resolved https://github.com/vicente-gonzalez-ruiz/self_fourier_shell_correlation to commit f785ed2aa883d5362036cc66d26498286c9a48ff
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show self_fourier_shell_correlation
# Out:
# Name: self_fourier_shell_correlation
# Version: 0.0.1
# Summary: Self Fourier shell correlation (https://www.nature.com/articles/s42003-023-05724-y)
# Home-page: https://github.com/vicente-gonzalez-ruiz/self_fourier_shell_correlation
# Author:
# Author-email: "Eric J. Verbeke" <ev9102@princeton.edu>, Vicente González Ruiz <vicente.gonzalez.ruiz@gmail.com>
# License:
# Location: /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages
# Requires:
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.executable)
# Out:
# /home/jupyter-vruiz/envs/cryoCARE/bin/python

# %%
# %pip install "shuffling @ git+https://github.com/vicente-gonzalez-ruiz/shuffling"
# Out:
# Collecting shuffling@ git+https://github.com/vicente-gonzalez-ruiz/shuffling
#   Cloning https://github.com/vicente-gonzalez-ruiz/shuffling to /tmp/pip-install-dtadk5k9/shuffling_d5c94df60a824c99999c3154183ecfcb
#   Running command git clone --filter=blob:none --quiet https://github.com/vicente-gonzalez-ruiz/shuffling /tmp/pip-install-dtadk5k9/shuffling_d5c94df60a824c99999c3154183ecfcb
#   Resolved https://github.com/vicente-gonzalez-ruiz/shuffling to commit 0710ed80bd40725b8fd116352c8e58a97f96528b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.0 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from opencv-python) (1.19.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install "motion_estimation @ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation"
# Out:
# Collecting motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation
#   Cloning https://github.com/vicente-gonzalez-ruiz/motion_estimation to /tmp/pip-install-a2l7e341/motion-estimation_96101f6c1852410685aef7c474fe6216
#   Running command git clone --filter=blob:none --quiet https://github.com/vicente-gonzalez-ruiz/motion_estimation /tmp/pip-install-a2l7e341/motion-estimation_96101f6c1852410685aef7c474fe6216
#   Resolved https://github.com/vicente-gonzalez-ruiz/motion_estimation to commit aa8deb4a9889d36b55c55b03c6497d61c034fa3d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (1.19.5)
# Requirement already satisfied: opencv-python in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (4.12.0.88)
# Requirement already satisfied: matplotlib in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (3.6.3)
# Requirement already satisfied: contourpy>=1.0.1 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (10.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from self_fourier_shell_correlation import fsc_utils as fsc

# %%
import mrcfile

# %%
import matplotlib.pyplot as plt

# %%
even = mrcfile.read("/nas/vruiz/cryoCARE/small_vol/even.mrc")

# %%
odd = mrcfile.read("/nas/vruiz/cryoCARE/small_vol/odd.mrc")

# %%
spatial_freq, fsc_values = fsc.fourier_shell_correlation(even, odd, shell_thickness=0.01)

# %%
fsc.plot_fsc(spatial_freq, fsc_values, "Spatial Frequency (1/voxel units)", "FSC", "FSC(even, odd)")
