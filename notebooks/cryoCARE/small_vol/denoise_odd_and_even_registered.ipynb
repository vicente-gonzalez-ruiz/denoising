# %% [markdown]
# # cryoCARE odd-and_even registered
# N2N (Noise2Noise) denoising del volumen small_vol. Utiliza 4 volúmenes:
#
# 1. $V_1$, con los planos Z pares ("even").
# 2. $V_2$, con los planos Z impares ("odd").
# 3. $V_3$, con los slices Z impares proyectados sobre los slices pares.
# 4. $V_4$, con los slices Z pares proyectados sobre los slices impares.
#
# Todos los ficheros temporales se crean en `/nas/vruiz/cryoCARE/small_vol`.

# %% [markdown]
# ## Creamos $V_2$
# El volumen "odd" proyectado. Para ello usamos los volúmenes even y odd ya generados previsamente en el experimento cryoCARE__even_odd.ipynb.

# %%
# %run project_odd_even_and_viceversa.ipynb
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /tmp/ipykernel_2627543/2129321884.py:1
# ----> 1 for z in tqdm(range(even_vol.shape[0]), desc="Projecting Slices"):
#       2
#       3     # Calculate the dense optical flow from slice_z_plus_1 to slice_z
#       4     flow = cv2.calcOpticalFlowFarneback(even_vol[z, ...], odd_vol[z, ...], None, **farneback_params)
#       6     # Create a remapping grid from the flow field
#
# File ~/envs/cryoCARE/lib/python3.8/site-packages/tqdm/notebook.py:234, in tqdm_notebook.__init__(self, *args, **kwargs)
#     232 unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     233 total = self.total * unit_scale if self.total else self.total
# --> 234 self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     235 self.container.pbar = proxy(self)
#     236 self.displayed = False
#
# File ~/envs/cryoCARE/lib/python3.8/site-packages/tqdm/notebook.py:108, in tqdm_notebook.status_printer(_, total, desc, ncols)
#      99 # Fallback to text bar if there's no total
#     100 # DEPRECATED: replaced with an 'info' style bar
#     101 # if not total:
#    (...)
#     105
#     106 # Prepare IPython progress bar
#     107 if IProgress is None:  # #187 #451 #558 #872
# --> 108     raise ImportError(WARN_NOIPYW)
#     109 if total:
#     110     pbar = IProgress(min=0, max=total)
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('run', 'project_odd_even_and_viceversa.ipynb')
#
# File ~/envs/cryoCARE/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2417, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2415     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2416 with self.builtin_trap:
# -> 2417     result = fn(*args, **kwargs)
#    2419 # The code below prevents the output from being displayed
#    2420 # when using magics with decodator @output_can_be_silenced
#    2421 # when the last Python token in the expression is a ';'.
#    2422 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/envs/cryoCARE/lib/python3.8/site-packages/IPython/core/magics/execution.py:722, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     720     with preserve_keys(self.shell.user_ns, '__file__'):
#     721         self.shell.user_ns['__file__'] = filename
# --> 722         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     723     return
#     725 # Control the response to exit() calls made by the script being run
#
# File ~/envs/cryoCARE/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2939, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2937 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2938 if raise_exceptions:
# -> 2939     result.raise_error()
#    2940 elif not result.success:
#    2941     break
#
# File ~/envs/cryoCARE/lib/python3.8/site-packages/IPython/core/interactiveshell.py:268, in ExecutionResult.raise_error(self)
#     266     raise self.error_before_exec
#     267 if self.error_in_exec is not None:
# --> 268     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File /tmp/ipykernel_2627543/2129321884.py:1
# ----> 1 for z in tqdm(range(even_vol.shape[0]), desc="Projecting Slices"):
#       2
#       3     # Calculate the dense optical flow from slice_z_plus_1 to slice_z
#       4     flow = cv2.calcOpticalFlowFarneback(even_vol[z, ...], odd_vol[z, ...], None, **farneback_params)
#       6     # Create a remapping grid from the flow field
#
# File ~/envs/cryoCARE/lib/python3.8/site-packages/tqdm/notebook.py:234, in tqdm_notebook.__init__(self, *args, **kwargs)
#     232 unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     233 total = self.total * unit_scale if self.total else self.total
# --> 234 self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     235 self.container.pbar = proxy(self)
#     236 self.displayed = False
#
# File ~/envs/cryoCARE/lib/python3.8/site-packages/tqdm/notebook.py:108, in tqdm_notebook.status_printer(_, total, desc, ncols)
#      99 # Fallback to text bar if there's no total
#     100 # DEPRECATED: replaced with an 'info' style bar
#     101 # if not total:
#    (...)
#     105
#     106 # Prepare IPython progress bar
#     107 if IProgress is None:  # #187 #451 #558 #872
# --> 108     raise ImportError(WARN_NOIPYW)
#     109 if total:
#     110     pbar = IProgress(min=0, max=total)
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %% [markdown]
# ## Configuramos cryoCARE

# %%
# %%writefile /nas/vruiz/cryoCARE/small_vol/train_data_config__odd_even_registered.json
# {
#     "even": ["even.mrc", "odd_registered.mrc"],
#     "odd": ["even_registered.mrc", "odd.mrc"],
#     "mask": [""],
#     "patch_shape": [8, 8, 8],
#     "num_slices": 800,
#     "split": 0.9,
#     "tilt_axis": "Y",
#     "n_normalization_samples": 200,
#     "path": "./odd_even_registered_data",
#     "overwrite": "True"
# }
# Out:
# Overwriting /nas/vruiz/cryoCARE/small_vol/train_data_config__odd_even_registered.json

# %%
# %%bash
# cd /nas/vruiz/cryoCARE/small_vol
# source ~/envs/cryoCARE/bin/activate
# cryoCARE_extract_train_data.py --conf train_data_config__odd_even_registered.json
# Out:
# 2025-10-21 11:52:50.000546: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# even.data.shape=(20, 256, 256), sample_shape=[8, 8, 8]
# even.data.shape=(20, 256, 256), sample_shape=[8, 8, 8]
# Computing normalization parameters:
# 100%|██████████| 200/200 [00:00<00:00, 18814.44it/s]

# %% [markdown]
# ## Entrenamos

# %%
# %%writefile /nas/vruiz/cryoCARE/small_vol/train_config__odd_even_registered.json
# {
#   "train_data": "./odd_even_registered_data",
#   "epochs": 50,
#   "steps_per_epoch": 200,
#   "batch_size": 16,
#   "unet_kern_size": 3,
#   "unet_n_depth": 3,
#   "unet_n_first": 16,
#   "learning_rate": 0.0004,
#   "model_name": "model",
#   "path": "./",
#   "gpu_id": [1]
# }
# Out:
# Writing /nas/vruiz/cryoCARE/small_vol/train_config__odd_even_registered.json

# %%
# %%bash
# cd /nas/vruiz/cryoCARE/small_vol
# source ~/envs/cryoCARE/bin/activate
# cryoCARE_train.py --conf train_config__odd_even_registered.json
# Out:
# 2025-10-21 11:53:06.878816: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-21 11:53:09.490443: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2025-10-21 11:53:09.491815: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2025-10-21 11:53:09.511067: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:53:09.512486: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:c1:00.0 name: NVIDIA A30 computeCapability: 8.0
# coreClock: 1.44GHz coreCount: 56 deviceMemorySize: 23.60GiB deviceMemoryBandwidth: 869.04GiB/s
# 2025-10-21 11:53:09.512557: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:53:09.512729: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:41:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.73GiB deviceMemoryBandwidth: 836.37GiB/s
# 2025-10-21 11:53:09.512745: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-21 11:53:09.518014: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-21 11:53:09.518048: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2025-10-21 11:53:09.520252: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2025-10-21 11:53:09.521640: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2025-10-21 11:53:09.525240: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2025-10-21 11:53:09.526930: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2025-10-21 11:53:09.528285: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-21 11:53:09.528379: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:53:09.530124: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:53:09.530347: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:53:09.531691: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:53:09.531852: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2025-10-21 11:53:09.558502: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2025-10-21 11:53:09.558623: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:53:09.558809: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:41:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.73GiB deviceMemoryBandwidth: 836.37GiB/s
# 2025-10-21 11:53:09.558826: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-21 11:53:09.558840: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-21 11:53:09.558850: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2025-10-21 11:53:09.558858: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2025-10-21 11:53:09.558867: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2025-10-21 11:53:09.558875: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2025-10-21 11:53:09.558883: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2025-10-21 11:53:09.558892: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-21 11:53:09.558946: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:53:09.559152: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:53:09.559309: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 1
# 2025-10-21 11:53:09.559344: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-21 11:53:10.050721: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-21 11:53:10.050766: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      1
# 2025-10-21 11:53:10.050774: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   N
# 2025-10-21 11:53:10.051052: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:53:10.051292: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:53:10.051506: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:53:10.051683: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 28520 MB memory) -> physical GPU (device: 1, name: Tesla V100-PCIE-32GB, pci bus id: 0000:41:00.0, compute capability: 7.0)
# WARNING:tensorflow:NCCL is not supported when using virtual GPUs, fallingback to reduction to one device
# 2025-10-21 11:53:10.285704: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:656] In AUTO-mode, and switching to DATA-based sharding, instead of FILE-based sharding as we cannot find appropriate reader dataset op(s) to shard. Error: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_2"
# op: "FlatMapDataset"
# input: "TensorDataset/_1"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_flat_map_fn_645"
#     }
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: 8
#         }
#         dim {
#           size: 8
#         }
#         dim {
#           size: 8
#         }
#         dim {
#           size: 1
#         }
#       }
#       shape {
#         dim {
#           size: 8
#         }
#         dim {
#           size: 8
#         }
#         dim {
#           size: 8
#         }
#         dim {
#           size: 1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_FLOAT
#       type: DT_FLOAT
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2025-10-21 11:53:10.294164: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2025-10-21 11:53:10.294493: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2595155000 Hz
# Looking for GPU with ID: 1
# GPU 1 successfully found
# 0 1
# 1 8
# 2 8
# 3 8
# 4 1
# Epoch 1/50
# 2025-10-21 11:53:13.155307: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-21 11:53:14.424945: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2025-10-21 11:53:14.482210: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2025-10-21 11:53:15.136422: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-21 11:53:15.473466: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2025-10-21 11:53:36.758065: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:656] In AUTO-mode, and switching to DATA-based sharding, instead of FILE-based sharding as we cannot find appropriate reader dataset op(s) to shard. Error: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_2"
# op: "FlatMapDataset"
# input: "TensorDataset/_1"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_flat_map_fn_689"
#     }
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: 8
#         }
#         dim {
#           size: 8
#         }
#         dim {
#           size: 8
#         }
#         dim {
#           size: 1
#         }
#       }
#       shape {
#         dim {
#           size: 8
#         }
#         dim {
#           size: 8
#         }
#         dim {
#           size: 8
#         }
#         dim {
#           size: 1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_FLOAT
#       type: DT_FLOAT
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 200/200 [==============================] - 38s 70ms/step - loss: 0.5632 - mse: 0.5632 - mae: 0.5580 - val_loss: 0.4861 - val_mse: 0.4861 - val_mae: 0.5317
# Epoch 2/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4541 - mse: 0.4541 - mae: 0.5163 - val_loss: 0.4627 - val_mse: 0.4627 - val_mae: 0.5206
# Epoch 3/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4420 - mse: 0.4420 - mae: 0.5111 - val_loss: 0.4597 - val_mse: 0.4597 - val_mae: 0.5185
# Epoch 4/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4391 - mse: 0.4391 - mae: 0.5096 - val_loss: 0.4561 - val_mse: 0.4561 - val_mae: 0.5171
# Epoch 5/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4377 - mse: 0.4377 - mae: 0.5084 - val_loss: 0.4558 - val_mse: 0.4558 - val_mae: 0.5169
# Epoch 6/50
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4350 - mse: 0.4350 - mae: 0.5070 - val_loss: 0.4557 - val_mse: 0.4557 - val_mae: 0.5151
# Epoch 7/50
# 200/200 [==============================] - 2s 9ms/step - loss: 0.4359 - mse: 0.4359 - mae: 0.5074 - val_loss: 0.4560 - val_mse: 0.4560 - val_mae: 0.5172
# Epoch 8/50
# 200/200 [==============================] - 2s 10ms/step - loss: 0.4355 - mse: 0.4355 - mae: 0.5074 - val_loss: 0.4522 - val_mse: 0.4522 - val_mae: 0.5148
# Epoch 9/50
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4335 - mse: 0.4335 - mae: 0.5058 - val_loss: 0.4538 - val_mse: 0.4538 - val_mae: 0.5141
# Epoch 10/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4336 - mse: 0.4336 - mae: 0.5061 - val_loss: 0.4543 - val_mse: 0.4543 - val_mae: 0.5142
# Epoch 11/50
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4324 - mse: 0.4324 - mae: 0.5049 - val_loss: 0.4569 - val_mse: 0.4569 - val_mae: 0.5173
# Epoch 12/50
# 200/200 [==============================] - 2s 10ms/step - loss: 0.4315 - mse: 0.4315 - mae: 0.5043 - val_loss: 0.4536 - val_mse: 0.4536 - val_mae: 0.5146
# Epoch 13/50
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4319 - mse: 0.4319 - mae: 0.5045 - val_loss: 0.4528 - val_mse: 0.4528 - val_mae: 0.5139
# Epoch 14/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4327 - mse: 0.4327 - mae: 0.5056 - val_loss: 0.4539 - val_mse: 0.4539 - val_mae: 0.5144
# Epoch 15/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4299 - mse: 0.4299 - mae: 0.5030 - val_loss: 0.4563 - val_mse: 0.4563 - val_mae: 0.5155
# Epoch 16/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4316 - mse: 0.4316 - mae: 0.5038 - val_loss: 0.4532 - val_mse: 0.4532 - val_mae: 0.5153
# Epoch 17/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4296 - mse: 0.4296 - mae: 0.5034 - val_loss: 0.4540 - val_mse: 0.4540 - val_mae: 0.5151
# Epoch 18/50
# 200/200 [==============================] - 3s 13ms/step - loss: 0.4315 - mse: 0.4315 - mae: 0.5055 - val_loss: 0.4535 - val_mse: 0.4535 - val_mae: 0.5149
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# Epoch 19/50
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4275 - mse: 0.4275 - mae: 0.5010 - val_loss: 0.4516 - val_mse: 0.4516 - val_mae: 0.5140
# Epoch 20/50
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4273 - mse: 0.4273 - mae: 0.5017 - val_loss: 0.4525 - val_mse: 0.4525 - val_mae: 0.5140
# Epoch 21/50
# 200/200 [==============================] - 2s 9ms/step - loss: 0.4280 - mse: 0.4280 - mae: 0.5025 - val_loss: 0.4535 - val_mse: 0.4535 - val_mae: 0.5150
# Epoch 22/50
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4277 - mse: 0.4277 - mae: 0.5016 - val_loss: 0.4501 - val_mse: 0.4501 - val_mae: 0.5127
# Epoch 23/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4286 - mse: 0.4286 - mae: 0.5031 - val_loss: 0.4523 - val_mse: 0.4523 - val_mae: 0.5136
# Epoch 24/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4249 - mse: 0.4249 - mae: 0.5004 - val_loss: 0.4531 - val_mse: 0.4531 - val_mae: 0.5143
# Epoch 25/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4246 - mse: 0.4246 - mae: 0.5005 - val_loss: 0.4529 - val_mse: 0.4529 - val_mae: 0.5139
# Epoch 26/50
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4240 - mse: 0.4240 - mae: 0.4994 - val_loss: 0.4522 - val_mse: 0.4522 - val_mae: 0.5144
# Epoch 27/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4258 - mse: 0.4258 - mae: 0.5009 - val_loss: 0.4536 - val_mse: 0.4536 - val_mae: 0.5140
# Epoch 28/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4241 - mse: 0.4241 - mae: 0.4999 - val_loss: 0.4535 - val_mse: 0.4535 - val_mae: 0.5141
# Epoch 29/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4206 - mse: 0.4206 - mae: 0.4975 - val_loss: 0.4559 - val_mse: 0.4559 - val_mae: 0.5165
# Epoch 30/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4259 - mse: 0.4259 - mae: 0.5022 - val_loss: 0.4556 - val_mse: 0.4556 - val_mae: 0.5157
# Epoch 31/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4210 - mse: 0.4210 - mae: 0.4973 - val_loss: 0.4537 - val_mse: 0.4537 - val_mae: 0.5149
# Epoch 32/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4219 - mse: 0.4219 - mae: 0.4984 - val_loss: 0.4560 - val_mse: 0.4560 - val_mae: 0.5163
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 33/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4187 - mse: 0.4187 - mae: 0.4963 - val_loss: 0.4558 - val_mse: 0.4558 - val_mae: 0.5162
# Epoch 34/50
# 200/200 [==============================] - 2s 10ms/step - loss: 0.4203 - mse: 0.4203 - mae: 0.4977 - val_loss: 0.4562 - val_mse: 0.4562 - val_mae: 0.5164
# Epoch 35/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4173 - mse: 0.4173 - mae: 0.4958 - val_loss: 0.4576 - val_mse: 0.4576 - val_mae: 0.5167
# Epoch 36/50
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4192 - mse: 0.4192 - mae: 0.4971 - val_loss: 0.4579 - val_mse: 0.4579 - val_mae: 0.5169
# Epoch 37/50
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4191 - mse: 0.4191 - mae: 0.4977 - val_loss: 0.4582 - val_mse: 0.4582 - val_mae: 0.5173
# Epoch 38/50
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4160 - mse: 0.4160 - mae: 0.4953 - val_loss: 0.4577 - val_mse: 0.4577 - val_mae: 0.5175
# Epoch 39/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4169 - mse: 0.4169 - mae: 0.4957 - val_loss: 0.4582 - val_mse: 0.4582 - val_mae: 0.5173
# Epoch 40/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4140 - mse: 0.4140 - mae: 0.4932 - val_loss: 0.4597 - val_mse: 0.4597 - val_mae: 0.5182
# Epoch 41/50
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4149 - mse: 0.4149 - mae: 0.4946 - val_loss: 0.4613 - val_mse: 0.4613 - val_mae: 0.5191
# Epoch 42/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4134 - mse: 0.4134 - mae: 0.4934 - val_loss: 0.4593 - val_mse: 0.4593 - val_mae: 0.5175
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 43/50
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4122 - mse: 0.4122 - mae: 0.4924 - val_loss: 0.4607 - val_mse: 0.4607 - val_mae: 0.5193
# Epoch 44/50
# 200/200 [==============================] - 2s 10ms/step - loss: 0.4125 - mse: 0.4125 - mae: 0.4929 - val_loss: 0.4591 - val_mse: 0.4591 - val_mae: 0.5182
# Epoch 45/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4152 - mse: 0.4152 - mae: 0.4946 - val_loss: 0.4618 - val_mse: 0.4618 - val_mae: 0.5190
# Epoch 46/50
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4132 - mse: 0.4132 - mae: 0.4934 - val_loss: 0.4606 - val_mse: 0.4606 - val_mae: 0.5188
# Epoch 47/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4106 - mse: 0.4106 - mae: 0.4920 - val_loss: 0.4613 - val_mse: 0.4613 - val_mae: 0.5186
# Epoch 48/50
# 200/200 [==============================] - 2s 12ms/step - loss: 0.4147 - mse: 0.4147 - mae: 0.4948 - val_loss: 0.4626 - val_mse: 0.4626 - val_mae: 0.5198
# Epoch 49/50
# 200/200 [==============================] - 3s 13ms/step - loss: 0.4134 - mse: 0.4134 - mae: 0.4931 - val_loss: 0.4632 - val_mse: 0.4632 - val_mae: 0.5202
# Epoch 50/50
# 200/200 [==============================] - 2s 11ms/step - loss: 0.4100 - mse: 0.4100 - mae: 0.4920 - val_loss: 0.4617 - val_mse: 0.4617 - val_mae: 0.5200
# /home/jupyter-vruiz/envs/cryoCARE/lib/python3.8/site-packages/csbdeep/models/base_model.py:149: UserWarning: output path for model already exists, files may be overwritten: /nas/vruiz/cryoCARE/small_vol/model
#   warnings.warn('output path for model already exists, files may be overwritten: %s' % str(self.logdir.resolve()))
# Loading network weights from 'weights_best.h5'.

# %% [markdown]
# ## Inferimos

# %%
# %%writefile /nas/vruiz/cryoCARE/small_vol/predict_config__odd_even_registered.json
# {
#     "path": "./model.tar.gz",
#     "even": ["small_vol.mrc"],
#     "odd": ["small_vol.mrc"],
#     "n_tiles": [1,1,1],
#     "output": "odd_even_registered_denoised",
#     "overwrite": "True",
#     "gpu_id": [1]
# }
# Out:
# Overwriting /nas/vruiz/cryoCARE/small_vol/predict_config__odd_even_registered.json

# %%
# %%bash
# cd /nas/vruiz/cryoCARE/small_vol
# pwd
# source ~/envs/cryoCARE/bin/activate
# cryoCARE_predict.py --conf predict_config__odd_even_registered.json || true
# Out:
# /nas/vruiz/cryoCARE/small_vol
# 2025-10-21 11:56:01.836087: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-21 11:56:07.219944: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2025-10-21 11:56:07.220671: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2025-10-21 11:56:07.241476: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:56:07.242720: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:c1:00.0 name: NVIDIA A30 computeCapability: 8.0
# coreClock: 1.44GHz coreCount: 56 deviceMemorySize: 23.60GiB deviceMemoryBandwidth: 869.04GiB/s
# 2025-10-21 11:56:07.242791: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:56:07.242962: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:41:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.73GiB deviceMemoryBandwidth: 836.37GiB/s
# 2025-10-21 11:56:07.242977: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-21 11:56:07.247451: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-21 11:56:07.247486: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2025-10-21 11:56:07.249741: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2025-10-21 11:56:07.251454: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2025-10-21 11:56:07.254918: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2025-10-21 11:56:07.256751: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2025-10-21 11:56:07.257932: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-21 11:56:07.258017: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:56:07.259239: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:56:07.259470: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:56:07.260638: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:56:07.260799: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2025-10-21 11:56:07.353005: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2025-10-21 11:56:07.353149: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:56:07.353362: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:41:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.73GiB deviceMemoryBandwidth: 836.37GiB/s
# 2025-10-21 11:56:07.353381: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-21 11:56:07.353404: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-21 11:56:07.353413: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2025-10-21 11:56:07.353421: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2025-10-21 11:56:07.353429: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2025-10-21 11:56:07.353437: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2025-10-21 11:56:07.353445: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2025-10-21 11:56:07.353453: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-21 11:56:07.353518: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:56:07.353733: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:56:07.353895: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 1
# 2025-10-21 11:56:07.353927: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-21 11:56:07.856987: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-21 11:56:07.857025: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      1
# 2025-10-21 11:56:07.857033: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   N
# 2025-10-21 11:56:07.857280: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:56:07.857532: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:56:07.857739: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-21 11:56:07.857913: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 28520 MB memory) -> physical GPU (device: 1, name: Tesla V100-PCIE-32GB, pci bus id: 0000:41:00.0, compute capability: 7.0)
# 2025-10-21 11:56:08.024363: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2025-10-21 11:56:08.024744: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2595155000 Hz
# 2025-10-21 11:56:08.182747: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-21 11:56:09.417994: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2025-10-21 11:56:09.474335: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2025-10-21 11:56:10.181664: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-21 11:56:10.471114: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# Looking for GPU with ID: 1
# GPU 1 successfully found
# Loading network weights from 'weights_best.h5'.
# (32, 256, 256, 1)
# ['' '' '' '' '' '' '' ''
#  'cryoCARE                                                21-Oct-25  11:56:20     '
#  '']

# %%
import mrcfile
import numpy as np
import matplotlib.pyplot as plt

# %%
def read_MRC(path_file):
    return mrcfile.read(mrc_file_path)

# %%
mrc_file_path = '/nas/vruiz/cryoCARE/small_vol/small_vol.mrc'
original_vol = read_MRC(mrc_file_path)

# %%
mrc_file_path = '/nas/vruiz/cryoCARE/small_vol/odd_even_registered_denoised/small_vol.mrc'
denoised_vol = read_MRC(mrc_file_path)

# %%
# Choose a slice index in the middle of the volume for a good comparison
slice_idx = original_vol.shape[0] // 2

fig, axes = plt.subplots(1, 2, figsize=(20, 20))

# Plot the original slice z
im1 = axes[0].imshow(original_vol[slice_idx, :, :].T, cmap='gray', origin='lower')
axes[0].set_title(f'Original Slice Z={slice_idx}')
axes[0].grid(False)

# Plot the original slice z+1
im2 = axes[1].imshow(denoised_vol[slice_idx, :, :].T, cmap='gray', origin='lower')
axes[1].set_title(f'N2N-Odd-Even-Registered Denoised Slice Z={slice_idx}')
axes[1].grid(False)

plt.tight_layout()
plt.show()

# %%
slice_idx = original_vol.shape[0] // 2

fig, axes = plt.subplots(1, 2, figsize=(20, 20))

# Plot the original slice z
im1 = axes[0].imshow(original_vol[slice_idx, :256, :256].T, cmap='gray', origin='lower')
axes[0].set_title(f'Original Slice Z={slice_idx}')
axes[0].grid(False)

# Plot the original slice z+1
im2 = axes[1].imshow(denoised_vol[slice_idx, :256, :256].T, cmap='gray', origin='lower')
axes[1].set_title(f'N2N-Odd-Even-Registered Denoised Slice Z={slice_idx}')
axes[1].grid(False)

plt.tight_layout()
plt.show()

# %%
slice_idx = original_vol.shape[0] // 2

fig, axes = plt.subplots(1, 2, figsize=(20, 20))

# Plot the original slice z
im1 = axes[0].imshow(original_vol[slice_idx, 500:1000, 1000:1500].T, cmap='gray', origin='lower')
axes[0].set_title(f'Original Slice Z={slice_idx}')
axes[0].grid(False)

# Plot the original slice z+1
im2 = axes[1].imshow(denoised_vol[slice_idx, 500:1000, 1000:1500].T, cmap='gray', origin='lower')
axes[1].set_title(f'N2N-Odd-Even-Registered Denoised Slice Z={slice_idx}')
axes[1].grid(False)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2627543/2484330788.py:6: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   im1 = axes[0].imshow(original_vol[slice_idx, 500:1000, 1000:1500].T, cmap='gray', origin='lower')
# /tmp/ipykernel_2627543/2484330788.py:6: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   im1 = axes[0].imshow(original_vol[slice_idx, 500:1000, 1000:1500].T, cmap='gray', origin='lower')
# /tmp/ipykernel_2627543/2484330788.py:11: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   im2 = axes[1].imshow(denoised_vol[slice_idx, 500:1000, 1000:1500].T, cmap='gray', origin='lower')
# /tmp/ipykernel_2627543/2484330788.py:11: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   im2 = axes[1].imshow(denoised_vol[slice_idx, 500:1000, 1000:1500].T, cmap='gray', origin='lower')
